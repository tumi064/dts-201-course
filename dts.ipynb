# %% [markdown]
# class 1

# %%
ages = [19, 22, 21, 35, 28, 24, 31, 19, 27, 40]

count = len(ages)
print("Number of people:", count)

total = sum(ages)
print("Total:", total)

mean = total / count
print(f"Mean age: {mean:.1f}")

youngest = min(ages)
oldest = max(ages)
print("Youngest:", youngest)
print("Oldest:", oldest)

import statistics
median = statistics.median(ages)
print("Median:", median)
print("Different from mean?", median != mean)
# Out:
# Number of people: 10
# Total: 266
# Mean age: 26.6
# Youngest: 19
# Oldest: 40
# Median: 25.5
# Different from mean? True

# %% [markdown]
# class 2

# %%
import pandas as pd
df = pd.read_csv("50_startups.csv")
print(df.shape)

df.info()

print(df.isnull().sum())

col_series = df["Profit"]
col_dataframe = df[["Profit"]]

print(type(col_series))
print(col_series.shape)


print(type(col_dataframe))
print(col_dataframe.shape)

df.describe()

df.to_json("output.json", orient="records")
# Out:
# (50, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     str
#  4   Profit           50 non-null     float64
# dtypes: float64(4), str(1)
# memory usage: 2.1 KB
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64
# <class 'pandas.Series'>
# (50,)
# <class 'pandas.DataFrame'>
# (50, 1)

# %% [markdown]
# class 3

# %%
import pandas as pd

df = pd.read_excel("50_startups_messy.xlsx")
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())

df = df.drop_duplicates()
df["State"] = df["State"].str.strip().str.title()
df["Marketing Spend"] = pd.to_numeric(df["Marketing Spend"], errors="coerce")

sample_random = df.sample(n=20, random_state=7)
sample_stratified = df.groupby("State", group_keys=False).apply(lambda x: x.sample(frac=0.2, random_state=7))

print(df["R&D Spend"].mean())
print(sample_random["R&D Spend"].mean())
print(sample_stratified["R&D Spend"].mean())

print(df["Marketing Spend"].mean())
print(sample_random["Marketing Spend"].mean())
print(sample_stratified["Marketing Spend"].mean())
# Out:
# (50, 5)
# R&D Spend          0
# Administration     0
# Marketing Spend    1
# State              0
# Profit             0
# dtype: int64
# 0
# 73721.6156
# 76076.3745
# 44181.63888888888
# 207414.79085106382
# 239540.9310526316
# 146787.40555555554
